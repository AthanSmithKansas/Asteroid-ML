# %%
import numpy as np

# %%
2+2
# Out:
# 4

# %%
a = np.array([1, 2, 3])

# %%
print(a)
# Out:
# [1 2 3]

# %%
b=np.array([4, 5, 6])

# %%
print(b)
# Out:
# [4 5 6]

# %%
c = a @ b

# %%
print(c)
# Out:
# 32
